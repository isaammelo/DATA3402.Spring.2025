# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class counter:
    def __init__(self, maximum):
        self.maximum=maximum
        self.value=0
        
    def increment(self):
        if self.value<self.maximum:
            self.value+=1
        else:
            print("Cannot go beyond this value")

    def reset(self):
        self.value=0

# %%
# Testing
counter_x=counter(2) #limit is 2
print(counter_x.value)

counter_x.increment()
counter_x.increment()
counter_x.increment()
print(counter_x.value)
# Out:
# 0
# Cannot go beyond this value
# 2

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class counter:
    def __init__(self, maximum):
        self.__maximum=maximum 
        self.__value=0
        
    def increment(self):
        if self.__value<self.__maximum:
            self.__value+=1
        else:
            print("Cannot go beyond this value")

    def reset(self):
        self.__value=0

    def value(self):
        return self.__value

    def max_value(self):
        return self.__maximum

    def at_max(self):
        return self.__value==self.__maximum

# %%
# Testing
counter_x=counter(3) #limit is 3

print(counter_x.value())
print(counter_x.max_value())
print(counter_x.at_max())

counter_x.increment()
counter_x.increment()
counter_x.increment()

print(counter_x.value())
print(counter_x.at_max())

counter_x.increment()
# Out:
# 0
# 3
# False
# 3
# True
# Cannot go beyond this value

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class rectangle:
    def __init__(self, length, width, x, y):
        self.__length=length 
        self.__width=width 
        self.__x=x
        self.__y=y

    def length(self):
        return self.__length

    def width(self):
        return self.__width

    def coordinates(self):
        return (self.__x, self.__y)

    def area(self):
        return self.__length*self.__width

    def perimeter(self):
        return 2*(self.__length+self.__width)

# %%
# Testing 
r=rectangle(10, 5, 3, 5)
print("Length is", r.length())
print("Width is", r.width())
print("Coordinates are", r.coordinates())
print("Area is", r.area())
print("Perimeter is", r.perimeter())
# Out:
# Length is 10
# Width is 5
# Coordinates are (3, 5)
# Area is 50
# Perimeter is 30

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
import math #for pi

class Circle:
    def __init__(self, x, y, radius):
        self.__x=x
        self.__y=y
        self.__radius=radius 

    def radius(self):
        return self.__radius 

    def xycoordinates(self):
        return (self.__x, self.__y)

    def area (self):
        return math.pi*self.__radius**2

    def circumference(self):
        return 2*math.pi*self.__radius

# %%
# Testing 
circle=Circle(5, 5, 10)
print("Radius is", circle.radius())
print("Coordinates are", circle.xycoordinates())
print("Area is", circle.area())
print("Circumference is", circle.circumference())
# Out:
# Radius is 10
# Coordinates are (5, 5)
# Area is 314.1592653589793
# Circumference is 62.83185307179586

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
class shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y

    def coordinates(self):
        return (self.__x, self.__y)

class rectangle(shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y)
        self.__length=length
        self.__width=width 

    def length(self):
        return self.__length 

    def width(self):
        return self.__width 

    def area(self):
        return self.__length*self.__width

    def perimeter(self):
        return 2*(self.__length+self.__width)

class Circle(shape):
    def __init__(self, x, y, radius):
        super().__init__(x, y)
        self.__radius=radius

    def radius(self):
        return self.__radius

    def area(self):
        return math.pi*self.__radius**2

    def circumference(self):
        return 2*math.pi*self.__radius

# %%
# Testing 

r=rectangle(10, 5, 3, 5)
print("Length is", r.length())
print("Width is", r.width())
print("Coordinates are", r.coordinates())
print("Area is", r.area())
print("Perimeter is", r.perimeter())

circle=Circle(5, 5, 10)
print("Radius is", circle.radius())
print("Coordinates are", circle.coordinates())
print("Area is", circle.area())
print("Circumference is", circle.circumference())
# Out:
# Length is 10
# Width is 5
# Coordinates are (3, 5)
# Area is 50
# Perimeter is 30
# Radius is 10
# Coordinates are (5, 5)
# Area is 314.1592653589793
# Circumference is 62.83185307179586

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y

    def coordinates(self):
        return (self.__x, self.__y)

class rectangle(shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y)
        self.__length=length
        self.__width=width 

    def length(self):
        return self.__length 

    def width(self):
        return self.__width 

    def area(self):
        return self.__length*self.__width

    def perimeter(self):
        return 2*(self.__length+self.__width)

class Circle(shape):
    def __init__(self, x, y, radius):
        super().__init__(x, y)
        self.__radius=radius

    def radius(self):
        return self.__radius

    def area(self):
        return math.pi*self.__radius**2

    def circumference(self):
        return 2*math.pi*self.__radius

class Triangle(shape):
    def __init__(self, base, height, x, y):
        super().__init__(x, y)
        self.__base=base
        self.__height=height

    def base(self):
        return self.__base

    def height(self):
        return self.__height

    def area(self):
        return self.__base*self.__height*0.5

    def perimeter(self, side1, side2):
        return side1+side2+self.__base

# %%
# Testing 
r = rectangle(10, 5, 3, 5)
print("Rectangle Length is", r.length())
print("Rectangle Width is", r.width())
print("Rectangle Coordinates are", r.coordinates())
print("Rectangle Area is", r.area())
print("Rectangle Perimeter is", r.perimeter())

circle = Circle(5, 5, 10)
print("Circle Radius is", circle.radius())
print("Circle Coordinates are", circle.coordinates())
print("Circle Area is", circle.area())
print("Circle Circumference is", circle.circumference())

triangle=Triangle(5, 5, 5, 5)
print("Triangle Base is", triangle.base())
print("Triangle Height is", triangle.height())
print("Triangle Area is", triangle.area())
print("Triangle Perimeter is", triangle.perimeter(6, 7))
print("Triangle Coordinates are", triangle.coordinates())
# Out:
# Rectangle Length is 10
# Rectangle Width is 5
# Rectangle Coordinates are (3, 5)
# Rectangle Area is 50
# Rectangle Perimeter is 30
# Circle Radius is 10
# Circle Coordinates are (5, 5)
# Circle Area is 314.1592653589793
# Circle Circumference is 62.83185307179586
# Triangle Base is 5
# Triangle Height is 5
# Triangle Area is 12.5
# Triangle Perimeter is 18
# Triangle Coordinates are (5, 5)

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
class shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y

    def coordinates(self):
        return (self.__x, self.__y)

    def parameter(self):
        raise NotImplementedError("Implement in every subclass.") 

class rectangle(shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y)
        self.__length=length
        self.__width=width 

    def length(self):
        return self.__length 

    def width(self):
        return self.__width 

    def area(self):
        return self.__length*self.__width

    def perimeter(self):
        return 2*(self.__length+self.__width)

    def parameter(self): 
        x, y=self.coordinates()
        return [
            (x, y), 
            (x+self.__length, y),
            (x, y+self.__width),
            (x+self.__length, y+self.__width), 
            (x+self.__length//2, y), 
            (x+self.__length//2, y+self.__width), 
            (x, y+self.__width//2), 
            (x+self.__length, y+self.__width//2)
        ]

class Circle(shape):
    def __init__(self, x, y, radius):
        super().__init__(x, y)
        self.__radius=radius

    def radius(self):
        return self.__radius

    def area(self):
        return math.pi*self.__radius**2

    def circumference(self):
        return 2*math.pi*self.__radius

    def parameter(self):
        x, y=self.coordinates()
        points=[]
        pairs=16

        for i in range (pairs):
            angle=(2*math.pi*i)/pairs
            px=x+self.__radius*math.cos(angle)
            py=y+self.__radius*math.sin(angle)
            points.append((round(px, 2), round(py, 2)))

        return points

class Triangle(shape):
    def __init__(self, base, height, x, y):
        super().__init__(x, y)
        self.__base=base
        self.__height=height

    def base(self):
        return self.__base

    def height(self):
        return self.__height

    def area(self):
        return self.__base*self.__height*0.5

    def perimeter(self, side1, side2):
        return side1+side2+self.__base

    def parameter(self):
        x, y=self.coordinates()
        points=[
            (x, y),
            (x+self.__base, y),
            (x+self.__base/2,y+self.__height)
        ]

        return points

# %%
# Testing 
r = rectangle(10, 5, 3, 5)
print("Rectangle Length is", r.length())
print("Rectangle Width is", r.width())
print("Rectangle Coordinates are", r.coordinates())
print("Rectangle Area is", r.area())
print("Rectangle Perimeter is", r.perimeter())
print("Rectangle Parameter points are", r.parameter())

circle = Circle(5, 5, 10)
print("Circle Radius is", circle.radius())
print("Circle Coordinates are", circle.coordinates())
print("Circle Area is", circle.area())
print("Circle Circumference is", circle.circumference())
print("Circle Parameter points are", circle.parameter())

triangle = Triangle(5, 5, 5, 5)
print("Triangle Base is", triangle.base())
print("Triangle Height is", triangle.height())
print("Triangle Area is", triangle.area())
print("Triangle Perimeter is", triangle.perimeter(5, 7))
print("Triangle Parameter points are", triangle.parameter())
# Out:
# Rectangle Length is 10
# Rectangle Width is 5
# Rectangle Coordinates are (3, 5)
# Rectangle Area is 50
# Rectangle Perimeter is 30
# Rectangle Parameter points are [(3, 5), (13, 5), (3, 10), (13, 10), (8, 5), (8, 10), (3, 7), (13, 7)]
# Circle Radius is 10
# Circle Coordinates are (5, 5)
# Circle Area is 314.1592653589793
# Circle Circumference is 62.83185307179586
# Circle Parameter points are [(15.0, 5.0), (14.24, 8.83), (12.07, 12.07), (8.83, 14.24), (5.0, 15.0), (1.17, 14.24), (-2.07, 12.07), (-4.24, 8.83), (-5.0, 5.0), (-4.24, 1.17), (-2.07, -2.07), (1.17, -4.24), (5.0, -5.0), (8.83, -4.24), (12.07, -2.07), (14.24, 1.17)]
# Triangle Base is 5
# Triangle Height is 5
# Triangle Area is 12.5
# Triangle Perimeter is 17
# Triangle Parameter points are [(5, 5), (10, 5), (7.5, 10)]

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
class shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y

    def coordinates(self):
        return (self.__x, self.__y)

    def parameter(self):
        raise NotImplementedError("Implement in every subclass.") 

    def inside_coordinates(self):
        raise NotImplementedError("Implement in every subclass.") 

class rectangle(shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y)
        self.__length=length
        self.__width=width 

    def length(self):
        return self.__length 

    def width(self):
        return self.__width 

    def area(self):
        return self.__length*self.__width

    def perimeter(self):
        return 2*(self.__length+self.__width)

    def parameter(self): 
        x, y=self.coordinates()
        return [
            (x, y), 
            (x+self.__length, y),
            (x, y+self.__width),
            (x+self.__length, y+self.__width), 
            (x+self.__length//2, y), 
            (x+self.__length//2, y+self.__width), 
            (x, y+self.__width//2), 
            (x+self.__length, y+self.__width//2)
        ]

    def inside_coordinates(self, x, y):
        r_x, r_y=self.coordinates()
        return r_x <= x <= r_x+self.__length and r_r <=y <= r_y+self.__width

class Circle(shape):
    def __init__(self, x, y, radius):
        super().__init__(x, y)
        self.__radius=radius

    def radius(self):
        return self.__radius

    def area(self):
        return math.pi*self.__radius**2

    def circumference(self):
        return 2*math.pi*self.__radius

    def parameter(self):
        x, y=self.coordinates()
        points=[]
        pairs=16

        for i in range (pairs):
            angle=(2*math.pi*i)/pairs
            px=x+self.__radius*math.cos(angle)
            py=y+self.__radius*math.sin(angle)
            points.append((round(px, 2), round(py, 2)))

        return points

    def inside_coordinates(self, x, y):
        c_x, c_y=self.coordinates()
        distance=math.sqrt((x-c_x)**2+(y==c_y)**2)
        return distance <= self.__radius

class Triangle(shape):
    def __init__(self, base, height, x, y):
        super().__init__(x, y)
        self.__base=base
        self.__height=height

    def base(self):
        return self.__base

    def height(self):
        return self.__height

    def area(self):
        return self.__base*self.__height*0.5

    def perimeter(self, side1, side2):
        return side1+side2+self.__base

    def parameter(self):
        x, y=self.coordinates()
        points=[
            (x, y),
            (x+self.__base, y),
            (x+self.__base/2,y+self.__height)
        ]

        return points

    def inside_coordinates(self, x, y):
        x1, y1=self.coordinates()
        x2, y2=x1+self.__base, y1
        x3, y3=x1+self.__base/22, y1+self.__height
        origin=self.area()
        area1=abs(x*(y1-y3)+x1*(y3-y)+x3*(y-y1))/2
        area2=abs(x*(y2-y3)+x1*(y3-y)+x3*(y-y1))/2
        area3=abs(x*(y1-y2)+x1*(y2-y)+x2*(y-y1))/2
        return area1+area2+area3==origin

# %%
# Testing 
r=rectangle(10, 5, 3, 5)
print(r.inside_coordinates(1, 5)) 

circle=Circle(5, 5, 10)
print(circle.inside_coordinates(5, 5)) 

triangle=Triangle(5, 5, 5, 5)
print(triangle.inside_coordinates(5, 4))
# Out:
# False
# True
# False

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
class shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y

    def coordinates(self):
        return (self.__x, self.__y)

    def parameter(self):
        raise NotImplementedError("Implement in every subclass.") 

    def inside_coordinates(self):
        raise NotImplementedError("Implement in every subclass.") 

    def overlap(self, other):
        raise NotImplementedError("Implement in every subclass.") 


class rectangle(shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y)
        self.__length=length
        self.__width=width 

    def length(self):
        return self.__length 

    def width(self):
        return self.__width 

    def area(self):
        return self.__length*self.__width

    def perimeter(self):
        return 2*(self.__length+self.__width)

    def parameter(self): 
        x, y=self.coordinates()
        return [
            (x, y), 
            (x+self.__length, y),
            (x, y+self.__width),
            (x+self.__length, y+self.__width), 
            (x+self.__length//2, y), 
            (x+self.__length//2, y+self.__width), 
            (x, y+self.__width//2), 
            (x+self.__length, y+self.__width//2)
        ]

    def inside_coordinates(self, x, y):
        r_x, r_y=self.coordinates()
        return r_x <= x <= r_x+self.__length and r_r <=y <= r_y+self.__width

    def overlap(self, other):
        if isinstance(other, rectangle):
            r_x, r_y=self.coordinates()
            r2_x, r2_y=other.coordinates()
            if (r_x < r2_x+other.__length and r_x+self.__length > r2_x and
                r_y < r2_y+other.__width and r_y+self.__width > r2_y):
                return True
            return False
        return False

            

class Circle(shape):
    def __init__(self, x, y, radius):
        super().__init__(x, y)
        self.__radius=radius

    def radius(self):
        return self.__radius

    def area(self):
        return math.pi*self.__radius**2

    def circumference(self):
        return 2*math.pi*self.__radius

    def parameter(self):
        x, y=self.coordinates()
        points=[]
        pairs=16

        for i in range (pairs):
            angle=(2*math.pi*i)/pairs
            px=x+self.__radius*math.cos(angle)
            py=y+self.__radius*math.sin(angle)
            points.append((round(px, 2), round(py, 2)))

        return points

    def inside_coordinates(self, x, y):
        c_x, c_y=self.coordinates()
        distance=math.sqrt((x-c_x)**2+(y==c_y)**2)
        return distance <= self.__radius

    def overlap(self, other):
        if isinstance(other, Circle):
            c_x, c_y=self.coordinates()
            c2_x, c2_y=other.coordinates()
            distance=math.sqrt((c_x - c2_x)**2 +(c_y - c2_y)**2)
            if distance <= (self.__radius+other.__radius):
                return True
            return False
        return False
     

class Triangle(shape):
    def __init__(self, base, height, x, y):
        super().__init__(x, y)
        self.__base=base
        self.__height=height

    def base(self):
        return self.__base

    def height(self):
        return self.__height

    def area(self):
        return self.__base*self.__height*0.5

    def perimeter(self, side1, side2):
        return side1+side2+self.__base

    def parameter(self):
        x, y=self.coordinates()
        points=[
            (x, y),
            (x+self.__base, y),
            (x+self.__base/2,y+self.__height)
        ]

        return points

    def inside_coordinates(self, x, y):
        x1, y1=self.coordinates()
        x2, y2=x1+self.__base, y1
        x3, y3=x1+self.__base/22, y1+self.__height
        origin=self.area()
        area1=abs(x*(y1-y3)+x1*(y3-y)+x3*(y-y1))/2
        area2=abs(x*(y2-y3)+x1*(y3-y)+x3*(y-y1))/2
        area3=abs(x*(y1-y2)+x1*(y2-y)+x2*(y-y1))/2
        return area1+area2+area3==origin

    def overlap(self, other):
        if isinstance(other, Triangle):
            
            return False
        return False

# %%
# Testing 
r1=rectangle(10, 5, 3, 5)
r2=rectangle(8, 2, 4, 7)
print(r1.overlap(r2))

c1=Circle(5, 5, 10)
c2=Circle(10, 5, 5)
print(c1.overlap(c2))  

t1=Triangle(5, 5, 1, 4)
t2=Triangle(5, 5, 5, 5)
print(t1.overlap(t2))
# Out:
# True
# True
# False

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
class Shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y

    def coordinates(self):
        return (self.__x, self.__y)

    def parameter(self):
        raise NotImplementedError("Implement in every subclass.") 

    def inside_coordinates(self):
        raise NotImplementedError("Implement in every subclass.") 

    def overlap(self, other):
        raise NotImplementedError("Implement in every subclass.") 


class rectangle(shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y)
        self.__length=length
        self.__width=width 

    def length(self):
        return self.__length 

    def width(self):
        return self.__width 

    def area(self):
        return self.__length*self.__width

    def perimeter(self):
        return 2*(self.__length+self.__width)

    def parameter(self): 
        x, y=self.coordinates()
        return [
            (x, y), 
            (x+self.__length, y),
            (x, y+self.__width),
            (x+self.__length, y+self.__width), 
            (x+self.__length//2, y), 
            (x+self.__length//2, y+self.__width), 
            (x, y+self.__width//2), 
            (x+self.__length, y+self.__width//2)
        ]

    def inside_coordinates(self, x, y):
        r_x, r_y=self.coordinates()
        return r_x <= x <= r_x+self.__length and r_y <=y <= r_y+self.__width

    def overlap(self, other):
        if isinstance(other, rectangle):
            r_x, r_y=self.coordinates()
            r2_x, r2_y=other.coordinates()
            if (r_x < r2_x+other.__length and r_x+self.__length > r2_x and
                r_y < r2_y+other.__width and r_y+self.__width > r2_y):
                return True
            return False
        return False

            

class Circle(shape):
    def __init__(self, x, y, radius):
        super().__init__(x, y)
        self.__radius=radius

    def radius(self):
        return self.__radius

    def area(self):
        return math.pi*self.__radius**2

    def circumference(self):
        return 2*math.pi*self.__radius

    def parameter(self):
        x, y=self.coordinates()
        points=[]
        pairs=16

        for i in range (pairs):
            angle=(2*math.pi*i)/pairs
            px=x+self.__radius*math.cos(angle)
            py=y+self.__radius*math.sin(angle)
            points.append((round(px, 2), round(py, 2)))

        return points

    def inside_coordinates(self, x, y):
        c_x, c_y=self.coordinates()
        distance=math.sqrt((x-c_x)**2+(y==c_y)**2)
        return distance <= self.__radius

    def overlap(self, other):
        if isinstance(other, Circle):
            c_x, c_y=self.coordinates()
            c2_x, c2_y=other.coordinates()
            distance=math.sqrt((c_x - c2_x)**2 +(c_y - c2_y)**2)
            if distance <= (self.__radius+other.__radius):
                return True
            return False
        return False
     

class Triangle(shape):
    def __init__(self, base, height, x, y):
        super().__init__(x, y)
        self.__base=base
        self.__height=height

    def base(self):
        return self.__base

    def height(self):
        return self.__height

    def area(self):
        return self.__base*self.__height*0.5

    def perimeter(self, side1, side2):
        return side1+side2+self.__base

    def parameter(self):
        x, y=self.coordinates()
        points=[
            (x, y),
            (x+self.__base, y),
            (x+self.__base/2,y+self.__height)
        ]

        return points

    def inside_coordinates(self, x, y):
        x1, y1=self.coordinates()
        x2, y2=x1+self.__base, y1
        x3, y3=x1+self.__base/22, y1+self.__height
        origin=self.area()
        area1=abs(x*(y1-y3)+x1*(y3-y)+x3*(y-y1))/2
        area2=abs(x*(y2-y3)+x1*(y3-y)+x3*(y-y1))/2
        area3=abs(x*(y1-y2)+x1*(y2-y)+x2*(y-y1))/2
        return area1+area2+area3==origin

    def overlap(self, other):
        if isinstance(other, Triangle):
            
            return False
        return False

class CompoundShape(shape):
    def __init__(self):
        self.shapes=[]

    def add(self, shape):
        if isinstance(shape, Shape):
            self.shapes.append(shape)

    def parameter(self):
        all_points=[]
        for shape in self.shapes:
            all_points.extend(shape.parameter()) 
        return all_points

    def inside_coordinates(self, x, y):
        for shape in self.shapes:
            if not shape.inside_coordinates(x, y):
                return False
        return True

    def overlap(self, other):
        for shape1 in self.shapes: 
            for shape2 in other.shapes:
                if shape1.overlap(shape2):
                    return True
        return False

class Canvas:
    def __init__(self):
        self.shapes=[] 

    def add_shape(self, shape):
        self.shapes.append(shape)
        
    def draw(self):
        for shape in self.shapes:
            print(f"Shape: {shape.__class__.__name__}, Coordinates: {shape.coordinates()}")

# %%
# Testing 

rect=rectangle(5, 2, 0, 0)  
circle=Circle(5, 5, 2) 
triangle=Triangle(8, 4, 1, 1)  

print("Rectangle:")
print(f"Coordinates: {rect.coordinates()}")
print(f"Area: {rect.area()}")
print(f"Perimeter: {rect.perimeter()}")
print(f"Inside (2, 2): {rect.inside_coordinates(2, 2)}")
print()

print("Circle:")
print(f"Coordinates: {circle.coordinates()}")
print(f"Area: {circle.area()}")
print(f"Circumference: {circle.circumference()}")
print(f"Inside (5, 5): {circle.inside_coordinates(5, 5)}")
print()

print("Triangle:")
print(f"Coordinates: {triangle.coordinates()}")
print(f"Area: {triangle.area()}")
print(f"Inside (3, 2): {triangle.inside_coordinates(3, 2)}")
print()

compound_shape=CompoundShape()
compound_shape.add(rect)
compound_shape.add(circle)
print("Testing CompoundShape:")
print(f"Overlap between compound shapes: {compound_shape.overlap(CompoundShape())}")

canvas=Canvas()
canvas.add_shape(rect)
canvas.add_shape(circle)
canvas.add_shape(triangle)
print("Canvas Draw:")
canvas.draw()
# Out:
# Rectangle:
# Coordinates: (0, 0)
# Area: 10
# Perimeter: 14
# Inside (2, 2): True
#
# Circle:
# Coordinates: (5, 5)
# Area: 12.566370614359172
# Circumference: 12.566370614359172
# Inside (5, 5): True
#
# Triangle:
# Coordinates: (1, 1)
# Area: 16.0
# Inside (3, 2): False
#
# Testing CompoundShape:
# Overlap between compound shapes: False
# Canvas Draw:
# Shape: rectangle, Coordinates: (0, 0)
# Shape: Circle, Coordinates: (5, 5)
# Shape: Triangle, Coordinates: (1, 1)

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
class Shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y

    def coordinates(self):
        return (self.__x, self.__y)

    def parameter(self):
        raise NotImplementedError("Implement in every subclass.") 

    def inside_coordinates(self):
        raise NotImplementedError("Implement in every subclass.") 

    def overlap(self, other):
        raise NotImplementedError("Implement in every subclass.") 


class rectangle(shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y)
        self.__length=length
        self.__width=width 

    def length(self):
        return self.__length 

    def width(self):
        return self.__width 

    def area(self):
        return self.__length*self.__width

    def perimeter(self):
        return 2*(self.__length+self.__width)

    def parameter(self): 
        x, y=self.coordinates()
        return [
            (x, y), 
            (x+self.__length, y),
            (x, y+self.__width),
            (x+self.__length, y+self.__width), 
            (x+self.__length//2, y), 
            (x+self.__length//2, y+self.__width), 
            (x, y+self.__width//2), 
            (x+self.__length, y+self.__width//2)
        ]

    def inside_coordinates(self, x, y):
        r_x, r_y=self.coordinates()
        return r_x <= x <= r_x+self.__length and r_y <=y <= r_y+self.__width

    def overlap(self, other):
        if isinstance(other, rectangle):
            r_x, r_y=self.coordinates()
            r2_x, r2_y=other.coordinates()
            if (r_x < r2_x+other.__length and r_x+self.__length > r2_x and
                r_y < r2_y+other.__width and r_y+self.__width > r2_y):
                return True
            return False
        return False

            

class Circle(shape):
    def __init__(self, x, y, radius):
        super().__init__(x, y)
        self.__radius=radius

    def radius(self):
        return self.__radius

    def area(self):
        return math.pi*self.__radius**2

    def circumference(self):
        return 2*math.pi*self.__radius

    def parameter(self):
        x, y=self.coordinates()
        points=[]
        pairs=16

        for i in range (pairs):
            angle=(2*math.pi*i)/pairs
            px=x+self.__radius*math.cos(angle)
            py=y+self.__radius*math.sin(angle)
            points.append((round(px, 2), round(py, 2)))

        return points

    def inside_coordinates(self, x, y):
        c_x, c_y=self.coordinates()
        distance=math.sqrt((x-c_x)**2+(y==c_y)**2)
        return distance <= self.__radius

    def overlap(self, other):
        if isinstance(other, Circle):
            c_x, c_y=self.coordinates()
            c2_x, c2_y=other.coordinates()
            distance=math.sqrt((c_x - c2_x)**2 +(c_y - c2_y)**2)
            if distance <= (self.__radius+other.__radius):
                return True
            return False
        return False
     

class Triangle(shape):
    def __init__(self, base, height, x, y):
        super().__init__(x, y)
        self.__base=base
        self.__height=height

    def base(self):
        return self.__base

    def height(self):
        return self.__height

    def area(self):
        return self.__base*self.__height*0.5

    def perimeter(self, side1, side2):
        return side1+side2+self.__base

    def parameter(self):
        x, y=self.coordinates()
        points=[
            (x, y),
            (x+self.__base, y),
            (x+self.__base/2,y+self.__height)
        ]

        return points

    def inside_coordinates(self, x, y):
        x1, y1=self.coordinates()
        x2, y2=x1+self.__base, y1
        x3, y3=x1+self.__base/22, y1+self.__height
        origin=self.area()
        area1=abs(x*(y1-y3)+x1*(y3-y)+x3*(y-y1))/2
        area2=abs(x*(y2-y3)+x1*(y3-y)+x3*(y-y1))/2
        area3=abs(x*(y1-y2)+x1*(y2-y)+x2*(y-y1))/2
        return area1+area2+area3==origin

    def overlap(self, other):
        if isinstance(other, Triangle):
            
            return False
        return False

class CompoundShape(shape):
    def __init__(self):
        self.shapes=[]

    def add(self, shape):
        if isinstance(shape, Shape):
            self.shapes.append(shape)

    def parameter(self):
        all_points=[]
        for shape in self.shapes:
            all_points.extend(shape.parameter()) 
        return all_points

    def inside_coordinates(self, x, y):
        for shape in self.shapes:
            if not shape.inside_coordinates(x, y):
                return False
        return True

    def overlap(self, other):
        for shape1 in self.shapes: 
            for shape2 in other.shapes:
                if shape1.overlap(shape2):
                    return True
        return False

class Canvas:
    def __init__(self):
        self.shapes=[] 

    def add_shape(self, shape):
        self.shapes.append(shape)
        
    def draw(self):
        for shape in self.shapes:
            print(f"Shape: {shape.__class__.__name__}, Coordinates: {shape.coordinates()}")

class RasterDrawing:
    def __init__(self):
        self.shapes=[]
    
    def add(self, shape):
        self.shapes.append(shape)
    
    def remove(self, shape):
        if shape in self.shapes:
            self.shapes.remove(shape)
    
    def paint(self):
        if not self.shapes:
            print("Error, no shapes.")
        for shape in self.shapes:
            print(f"Shape: {shape.__class__.__name__}, Coordinates: {shape.coordinates()}")

    def modify(self, index, new_shape):
        if 0 <= index < len(self.shapes):
            self.shapes[index]=new_shape
        else:
            print("Error, invalid index.")

# %%
# Testing 
rect=rectangle(5, 5, 0, 0)  
circle = Circle(6, 3, 2) 
triangle = Triangle(10, 5, 1, 1)  

drawing=RasterDrawing()

drawing.add(rect)
drawing.add(circle)
drawing.add(triangle)

print("Drawing:")
drawing.paint()
print()

new_rect=rectangle(6, 3, 0, 0) 
drawing.modify(0, new_rect)

print("New Drawing:")
drawing.paint()
print()

drawing.remove(triangle)

print("Drawing after Removing Triangle:")
drawing.paint()
# Out:
# Drawing:
# Shape: rectangle, Coordinates: (0, 0)
# Shape: Circle, Coordinates: (6, 3)
# Shape: Triangle, Coordinates: (1, 1)
#
# New Drawing:
# Shape: rectangle, Coordinates: (0, 0)
# Shape: Circle, Coordinates: (6, 3)
# Shape: Triangle, Coordinates: (1, 1)
#
# Drawing after Removing Triangle:
# Shape: rectangle, Coordinates: (0, 0)
# Shape: Circle, Coordinates: (6, 3)

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class Shape:
    def __init__(self, x, y):
        self.__x=x
        self.__y=y

    def coordinates(self):
        return (self.__x, self.__y)

    def parameter(self):
        raise NotImplementedError("Implement in every subclass.") 

    def inside_coordinates(self):
        raise NotImplementedError("Implement in every subclass.") 

    def overlap(self, other):
        raise NotImplementedError("Implement in every subclass.") 
        
    def __repr__(self):
        return f"{self.__class__.__name__}({repr(self.__x)}, {repr(self.__y)})"
      



class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y)
        self.__length=length
        self.__width=width 

    def length(self):
        return self.__length 

    def width(self):
        return self.__width 

    def area(self):
        return self.__length*self.__width

    def perimeter(self):
        return 2*(self.__length+self.__width)

    def parameter(self): 
        x, y=self.coordinates()
        return [
            (x, y), 
            (x+self.__length, y),
            (x, y+self.__width),
            (x+self.__length, y+self.__width), 
            (x+self.__length//2, y), 
            (x+self.__length//2, y+self.__width), 
            (x, y+self.__width//2), 
            (x+self.__length, y+self.__width//2)
        ]

    def inside_coordinates(self, x, y):
        r_x, r_y=self.coordinates()
        return r_x <= x <= r_x+self.__length and r_y <=y <= r_y+self.__width

    def overlap(self, other):
        if isinstance(other, rectangle):
            r_x, r_y=self.coordinates()
            r2_x, r2_y=other.coordinates()
            if (r_x < r2_x+other.__length and r_x+self.__length > r2_x and
                r_y < r2_y+other.__width and r_y+self.__width > r2_y):
                return True
            return False
        return False

            

class Circle(shape):
    def __init__(self, x, y, radius):
        super().__init__(x, y)
        self.__radius=radius

    def radius(self):
        return self.__radius

    def area(self):
        return math.pi*self.__radius**2

    def circumference(self):
        return 2*math.pi*self.__radius

    def parameter(self):
        x, y=self.coordinates()
        points=[]
        pairs=16

        for i in range (pairs):
            angle=(2*math.pi*i)/pairs
            px=x+self.__radius*math.cos(angle)
            py=y+self.__radius*math.sin(angle)
            points.append((round(px, 2), round(py, 2)))

        return points

    def inside_coordinates(self, x, y):
        c_x, c_y=self.coordinates()
        distance=math.sqrt((x-c_x)**2+(y==c_y)**2)
        return distance <= self.__radius

    def overlap(self, other):
        if isinstance(other, Circle):
            c_x, c_y=self.coordinates()
            c2_x, c2_y=other.coordinates()
            distance=math.sqrt((c_x - c2_x)**2 +(c_y - c2_y)**2)
            if distance <= (self.__radius+other.__radius):
                return True
            return False
        return False
     

class Triangle(shape):
    def __init__(self, base, height, x, y):
        super().__init__(x, y)
        self.__base=base
        self.__height=height

    def base(self):
        return self.__base

    def height(self):
        return self.__height

    def area(self):
        return self.__base*self.__height*0.5

    def perimeter(self, side1, side2):
        return side1+side2+self.__base

    def parameter(self):
        x, y=self.coordinates()
        points=[
            (x, y),
            (x+self.__base, y),
            (x+self.__base/2,y+self.__height)
        ]

        return points

    def inside_coordinates(self, x, y):
        x1, y1=self.coordinates()
        x2, y2=x1+self.__base, y1
        x3, y3=x1+self.__base/22, y1+self.__height
        origin=self.area()
        area1=abs(x*(y1-y3)+x1*(y3-y)+x3*(y-y1))/2
        area2=abs(x*(y2-y3)+x1*(y3-y)+x3*(y-y1))/2
        area3=abs(x*(y1-y2)+x1*(y2-y)+x2*(y-y1))/2
        return area1+area2+area3==origin

    def overlap(self, other):
        if isinstance(other, Triangle):
            
            return False
        return False

class CompoundShape(shape):
    def __init__(self):
        self.shapes=[]

    def add(self, shape):
        if isinstance(shape, Shape):
            self.shapes.append(shape)

    def parameter(self):
        all_points=[]
        for shape in self.shapes:
            all_points.extend(shape.parameter()) 
        return all_points

    def inside_coordinates(self, x, y):
        for shape in self.shapes:
            if not shape.inside_coordinates(x, y):
                return False
        return True

    def overlap(self, other):
        for shape1 in self.shapes: 
            for shape2 in other.shapes:
                if shape1.overlap(shape2):
                    return True
        return False

class Canvas:
    def __init__(self):
        self.shapes=[] 

    def add_shape(self, shape):
        self.shapes.append(shape)
        
    def draw(self):
        for shape in self.shapes:
            print(f"Shape: {shape.__class__.__name__}, Coordinates: {shape.coordinates()}")

class RasterDrawing:
    def __init__(self):
        self.shapes=[]
    
    def add(self, shape):
        self.shapes.append(shape)
    
    def remove(self, shape):
        if shape in self.shapes:
            self.shapes.remove(shape)
    
    def paint(self):
        if not self.shapes:
            print("Error, no shapes.")
        for shape in self.shapes:
            print(f"Shape: {shape.__class__.__name__}, Coordinates: {shape.coordinates()}")

    def modify(self, index, new_shape):
        if 0 <= index < len(self.shapes):
            self.shapes[index]=new_shape
        else:
            print("Error, invalid index.")

    def save(self, filename):
        with open(filename, "w") as f:
            for shape in self.shapes:
                f.write(repr(shape) + "\n") 

    def load(self, filename):
        with open(filename, "r") as f:
            content=f.readlines()
        for line in content:
            shape=eval(line.strip())
            self.add(shape)

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')
